# %% [markdown]
# <a href="https://colab.research.google.com/github/Miriamwilfredoo/MiriamHFC/blob/main/HFC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("readxl")
library(readxl)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
df<-read_excel("/bin/mydata/worldfoodsupply2.xls")
df
# Out:
# New names:
# • `` -> `...15`
#      File Code BLS Code BLS Region  BLS Region 2 Scenario Code Scenario
# 1    1         9        Argentina   Argentina     1            GISS
# 2    1         9        Argentina   Argentina     2            GISS
# 3    1         9        Argentina   Argentina     3            GISS
# 4    1         9        Argentina   Argentina     4            GISS
# 5    1         9        Argentina   Argentina     5            GFDL
# 6    1         9        Argentina   Argentina     6            GFDL
# 7    1         9        Argentina   Argentina     7            GFDL
# 8    1         9        Argentina   Argentina     8            GFDL
# 9    1         9        Argentina   Argentina     9            UKMO
# 10   1         9        Argentina   Argentina    10            UKMO
# 11   1         9        Argentina   Argentina    11            UKMO
# 12   1         9        Argentina   Argentina    12            UKMO
# ...

# %%
df<-read_excel("/bin/mydata/worldfoodsupply2.xls")
df$`BLS Region 2`
# Out:
# New names:
# • `` -> `...15`
#    [1] "Argentina"          "Argentina"          "Argentina"
#    [4] "Argentina"          "Argentina"          "Argentina"
#    [7] "Argentina"          "Argentina"          "Argentina"
#   [10] "Argentina"          "Argentina"          "Argentina"
#   [13] "Argentina"          "Argentina"          "Argentina"
#   [16] "Argentina"          "Argentina"          "Argentina"
#   [19] "Argentina"          "Argentina"          "Argentina"
#   [22] "Argentina"          "Argentina"          "Argentina"
#   [25] "Argentina"          "Argentina"          "Argentina"
#   [28] "Argentina"          "Argentina"          "Argentina"
#   [31] "Argentina"          "Argentina"          "Argentina"
#   [34] "Argentina"          "Brazil"             "Brazil"
#   [37] "Brazil"             "Brazil"             "Brazil"
#   [40] "Brazil"             "Brazil"             "Brazil"
#   [43] "Brazil"             "Brazil"             "Brazil"
# ...

# %% [markdown]
# ggplot is more avanced and replaces matplot in python

# %%
install.packages("ggplot2")
install.packages("GGally")
library(ggplot2)
library(GGally)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘patchwork’, ‘ggstats’, ‘plyr’
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
pp<-c("patchwork","ggstats","plyr")
install.packages(pp)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# to call up columns in R use either colnames or names to call up columns

# %%
colnames(df)
# Out:
#  [1] "File Code"         "BLS Code"          "BLS Region"
#  [4] "BLS Region 2"      "Scenario Code"     "Scenario"
#  [7] "Time_Slice"        "CO2 effects"       "CO2 ppm"
# [10] "Adapt- ation"      "wheat"             "rice"
# [13] "coarse grains"     "protein feed"      "...15"
# [16] "grains"            "four commo-dities"

# %%
names(df)
# Out:
#  [1] "File Code"         "BLS Code"          "BLS Region"
#  [4] "BLS Region 2"      "Scenario Code"     "Scenario"
#  [7] "Time_Slice"        "CO2 effects"       "CO2 ppm"
# [10] "Adapt- ation"      "wheat"             "rice"
# [13] "coarse grains"     "protein feed"      "...15"
# [16] "grains"            "four commo-dities"

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')

# %%
ggpairs(df,col)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# ...

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','wheat')

# %%
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','rice')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','protein feed')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','coarse grains')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','grains')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('CO2 ppm','four commo-dities')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','coarse grains')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','wheat')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','rice')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','rice')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','four commo-dities')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('protein feed','CO2 ppm')
ggpairs(df,col2)
# Out:
# plot without title

# %%
col=c('File Code','BLS Code','Scenario Code','Scenario','Time_Slice','CO2 effects','CO2 ppm','Adapt- ation','wheat','rice','coarse grains','protein feed','grains','four commo-dities')
col2=c('Adapt- ation','rice')
ggpairs(df,col2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
class(df$`Adapt- ation`)
# Out:
# [1] "character"

# %%
summary(df)
# Out:
#    File Code        BLS Code      BLS Region        BLS Region 2
#  Min.   : 1.00   Min.   :  9.0   Length:1088        Length:1088
#  1st Qu.: 8.75   1st Qu.:107.8   Class :character   Class :character
#  Median :16.50   Median :227.0   Mode  :character   Mode  :character
#  Mean   :16.50   Mean   :479.4
#  3rd Qu.:24.25   3rd Qu.:905.2
#  Max.   :32.00   Max.   :913.0
#  Scenario Code     Scenario          Time_Slice        CO2 effects
#  Min.   : 1.00   Length:1088        Length:1088        Length:1088
#  1st Qu.: 9.00   Class :character   Class :character   Class :character
#  Median :29.50   Mode  :character   Mode  :character   Mode  :character
#  Mean   :25.26
#  3rd Qu.:38.00
#  Max.   :46.00
#     CO2 ppm      Adapt- ation           wheat             rice
#  Min.   :330.0   Length:1088        Min.   :-73.00   Min.   :-73.00
#  1st Qu.:330.0   Class :character   1st Qu.:-17.00   1st Qu.:-15.00
#  Median :466.5   Mode  :character   Median : -7.00   Median : -7.00
# ...

# %%
from sklearn.model_Selection import train_test_split
from sklearn.linear_model mport LinerRegression
y=df
